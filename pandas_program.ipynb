# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {
    'Name': ['Ashok', 'Angel', 'Boopathy', 'sachin', 'rohith'],
    'Employee ID': [101, 102, 103, 104, 105],
    'Age': [30, 25, 35, 46, 42],
    'Salary': [np.nan, 60000, 100000, 70000, 55000],
    'Department': ['HR', 'IT', 'Finance', 'HR', 'IT']
}

# %%
df = pd.DataFrame(data)

# %%
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#        Name  Employee ID  Age    Salary Department
# 0     Ashok          101   30       NaN         HR
# 1     Angel          102   25   60000.0         IT
# 2  Boopathy          103   35  100000.0    Finance
# 3    sachin          104   46   70000.0         HR
# 4    rohith          105   42   55000.0         IT

# %%
df.fillna({'Age': df['Age'].mean(), 'Salary': df['Salary'].median()}, inplace=True)

# %%
print("\nCleaned DataFrame:")
print(df)
# Out:
# Cleaned DataFrame:
#        Name  Employee ID  Age    Salary Department
# 0     Ashok          101   30   65000.0         HR
# 1     Angel          102   25   60000.0         IT
# 2  Boopathy          103   35  100000.0    Finance
# 3    sachin          104   46   70000.0         HR
# 4    rohith          105   42   55000.0         IT

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['Name'], df['Salary'], color='skyblue')
plt.xlabel('Employee Name')
plt.ylabel('Salary')
plt.title('Employee Salary Growth')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
